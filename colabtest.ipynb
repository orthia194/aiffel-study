# %%
import urllib.request; exec(urllib.request.urlopen('https://aic-data.aiffel.io/api/colab/setup?t=a897wp5r').read().decode())
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# ⏳  터널 준비 확인 중...
#
# ✅  터널 생성 완료 — 이 탭은 열어두세요.
# ✅ 연결됐습니다 — 웹앱 탭으로 돌아가면 자동으로 이어집니다.
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2026 04:04:52] "OPTIONS /ping HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2026 04:04:52] "GET /ping HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2026 04:05:18] "GET /ping HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2026 04:05:43] "GET /ping HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2026 04:06:08] "GET /ping HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2026 04:06:33] "GET /ping HTTP/1.1" 200 -

# %%
import urllib.request; exec(urllib.request.urlopen('https://aic-data.aiffel.io/api/colab/setup?t=a897wp5r').read().decode())
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# ⏳  터널 준비 확인 중...
#
# ✅  터널 생성 완료 — 이 탭은 열어두세요.
# ✅ 연결됐습니다 — 웹앱 탭으로 돌아가면 자동으로 이어집니다.
